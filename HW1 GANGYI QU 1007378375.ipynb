# %% [markdown]
# //What's the data?
#
# - We play 3 roles of game, in each role, we continously pick one single choice for ten times and check the results for each role.
#
# //What's the update for the posterior in question?
#
# - We had done two rounds of Bayesian Analysis, in the Step 2 and 3 of our coding work.
#
# //Which one of the three choices will you try out? How will you choose?
#
# - By our analysis, since we know the probability of each choice, we will keep selecting the one with the highest winning probability

# %% [markdown]
# # Step 1: We assume the $\theta_A$ = 0.3 | $\theta_B$ =0.5 | $\theta_C$ = 0.8 | and sample each game 10 times and see the probability

# %%
import numpy as np
from scipy import stats

# since we unknown everything we will keep play each game ten times, and see the probability we get.
stats.binom(n=1,p= 0.3).rvs(size=1)
a = 0
for i in range(10):
    if stats.binom(n=1,p= 0.5).rvs(size=1) == 1:
        a = a+1
        
probA = a/10
print(probA)


stats.binom(n=1,p= 0.5).rvs(size=1)
b = 0
for i in range(10):
    if stats.binom(n=1,p= 0.5).rvs(size=1) == 1:

        b = b+1
        
probB = b/10
print(probB)


stats.binom(n=1,p= 0.8).rvs(size=1)
c = 0
for i in range(10):
    if stats.binom(n=1,p= 0.8).rvs(size=1) == 1:

        c = c+1
        
probC = c/10
print(probC)
# Out:
# 0.3
# 0.5
# 0.9

# %% [markdown]
# # Step 2: Start with uniform prior and analysis for one round (Initial Prior)

# %%
alpha,beta,n,x=1,1,10,3 # from we select A for 10 round,we win 3 rounds
parameter_domain = np.linspace(0,1,1001)
likelihood = stats.binom.pmf(n=10, k=3, p= parameter_domain )
prior = stats.beta(a=1,b=1).pdf(parameter_domain)
c = 11
joint = c*likelihood*prior
posterior = stats.beta(a=x+alpha,b=n-x+beta).pdf(parameter_domain)
plt.figure(figsize=(12,4)); plt.plot(parameter_domain, likelihood, label="likelihood"); plt.plot(parameter_domain, prior, label="prior"); plt.plot(parameter_domain, posterior, label="posterior"); plt.plot(parameter_domain, joint, linestyle="--", label="joint (times scalar "+str(c)+")"); plt.legend(); plt.title("A from Beta(1,1) to Beta(13,8)" );

# %%
alpha,beta,n,x=1,1,10,5 # from we select B for 10 round,we win 5 rounds
parameter_domain = np.linspace(0,1,1001)
likelihood = stats.binom.pmf(n=10, k=5, p= parameter_domain )
prior = stats.beta(a=1,b=1).pdf(parameter_domain)
c = 11
joint = c*likelihood*prior
posterior = stats.beta(a=x+alpha,b=n-x+beta).pdf(parameter_domain)
plt.figure(figsize=(12,4)); plt.plot(parameter_domain, likelihood, label="likelihood"); plt.plot(parameter_domain, prior, label="prior"); plt.plot(parameter_domain, posterior, label="posterior"); plt.plot(parameter_domain, joint, linestyle="--", label="joint (times scalar "+str(c)+")"); plt.legend(); plt.title("B from Beta(1,1) to Beta(15,6)");

# %%
alpha,beta,n,x=1,1,10,8 # from we select C for 10 round,we win 8 rounds
parameter_domain = np.linspace(0,1,1001)
likelihood = stats.binom.pmf(n=10, k=8, p= parameter_domain )
prior = stats.beta(a=1,b=1).pdf(parameter_domain)
c = 11
joint = c*likelihood*prior
posterior = stats.beta(a=x+alpha,b=n-x+beta).pdf(parameter_domain)
plt.figure(figsize=(12,4)); plt.plot(parameter_domain, likelihood, label="likelihood"); plt.plot(parameter_domain, prior, label="prior"); plt.plot(parameter_domain, posterior, label="posterior"); plt.plot(parameter_domain, joint, linestyle="--", label="joint (times scalar "+str(c)+")"); plt.legend(); plt.title("C from Beta(1,1) to Beta(9,3)");

# %% [markdown]
# # Step 3: We will do another round of analysis for each choice

# %%
alpha,beta,n,x=13,8,10,3 # from we select A for 10 round,we win 3 rounds
parameter_domain = np.linspace(0,1,1001)
likelihood = stats.binom.pmf(n=10, k=3, p= parameter_domain )
prior = stats.beta(a=13,b=8).pdf(parameter_domain)
c = 19
joint = c*likelihood*prior
posterior = stats.beta(a=x+alpha,b=n-x+beta).pdf(parameter_domain)

plt.figure(figsize=(12,4)); plt.plot(parameter_domain, likelihood, label="likelihood"); plt.plot(parameter_domain, prior, label="prior"); plt.plot(parameter_domain, posterior, label="posterior"); plt.plot(parameter_domain, joint, linestyle="--", label="joint (times scalar "+str(c)+")"); plt.legend(); plt.title("A from Beta(13,8) to Beta(16,15)");

# %%
alpha,beta,n,x=15,6,10,5 # from we select B for 10 round,we win 5 rounds
parameter_domain = np.linspace(0,1,1001)
likelihood = stats.binom.pmf(n=10, k=5, p= parameter_domain )
prior = stats.beta(a=15,b=6).pdf(parameter_domain)
c = 10
joint = c*likelihood*prior
posterior = stats.beta(a=x+alpha,b=n-x+beta).pdf(parameter_domain)

plt.figure(figsize=(12,4)); plt.plot(parameter_domain, likelihood, label="likelihood"); plt.plot(parameter_domain, prior, label="prior"); plt.plot(parameter_domain, posterior, label="posterior"); plt.plot(parameter_domain, joint, linestyle="--", label="joint (times scalar "+str(c)+")"); plt.legend(); plt.title("B from Beta(15,6) to Beta(20,11)");

# %%
alpha,beta,n,x=9,3,10,8 # from we select C for 10 round,we win 8 rounds
parameter_domain = np.linspace(0,1,1001)
likelihood = stats.binom.pmf(n=10, k=8, p= parameter_domain )
prior = stats.beta(a=9,b=3).pdf(parameter_domain)
c = 4.5
joint = c*likelihood*prior
posterior = stats.beta(a=x+alpha,b=n-x+beta).pdf(parameter_domain)
plt.figure(figsize=(12,4)); plt.plot(parameter_domain, likelihood, label="likelihood"); plt.plot(parameter_domain, prior, label="prior"); plt.plot(parameter_domain, posterior, label="posterior"); plt.plot(parameter_domain, joint, linestyle="--", label="joint (times scalar "+str(c)+")"); plt.legend(); plt.title("C from Beta(9,3) to Beta(17,5)");
